# %% [markdown]
# # Prétraitement des données scrapées

# %%
# Importer les bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## 1. Importer les données scrapées

# %%
data_path = "../data/raw_data/autohero.csv  "
df = pd.read_csv(data_path, sep=",", encoding="utf-8")

# %%
df.head()
# Out:
#    scraped_at             modele                     finition      prix  \
# 0  2025-04-09        Ford Fiesta       1.0 EcoBoost ST-Line X  13 190 €
# 1  2025-04-09      Toyota ProAce  Combi Long 1.5 D-4D Dynamic  23 990 €
# 2  2025-04-09  Mercedes-Benz GLA        250 e AMG Line 8G-DCT  32 490 €
# 3  2025-04-09             BMW X1         sDrive18i xLine DKG7  27 890 €
# 4  2025-04-09       Peugeot 3008   1.5 Blue-HDi Crossway EAT8  19 090 €
#
#   annee_mise_en_circulation kilometrage carburant  \
# 0                15.05.2020   69 301 km   Essence
# 1                29.04.2021   71 887 km    Diesel
# 2                23.10.2020   59 649 km   Hybride
# 3                05.05.2021   37 869 km   Essence
# 4                31.12.2019   58 958 km    Diesel
#
#                    transmission        puissance nb_ancien_proprietaire  \
# 0     Boite de vitesse manuelle    95 CV / 70 kW                      3
# 1     Boite de vitesse manuelle   120 CV / 88 kW                      2
# 2        Double embrayage / DCT  218 CV / 160 kW                      2
# 3        Double embrayage / DCT  136 CV / 100 kW                      2
# 4  Boite de vitesse automatique   130 CV / 96 kW                      3
#
#   classe_vehicule  nb_porte  nb_place couleur                      sellerie  \
# 0        Citadine       5.0       5.0    Gris    Tissu (Sellerie d'origine)
# 1       Monospace       4.0       9.0    Gris    Tissu (Sellerie d'origine)
# 2             SUV       5.0       5.0    Gris  Mi-cuir (Sellerie d'origine)
# 3             SUV       5.0       5.0    Noir  Mi-cuir (Sellerie d'origine)
# 4             SUV       5.0       5.0   Blanc  Mi-cuir (Sellerie d'origine)
#
#   classe_emission emission_CO2    crit_air usage_commerciale_anterieure  \
# 0          EURO 6          NaN  Crit'Air 1                          NaN
# 1          EURO 6     170 g/km  Crit'Air 2                          Oui
# 2          EURO 6      32 g/km  Crit'Air 1                          Oui
# 3          EURO 6     148 g/km  Crit'Air 1                          Non
# 4          EURO 6      98 g/km  Crit'Air 2                          Oui
#
#                                          url_annonce
# 0  https://www.autohero.com/fr/ford-fiesta/id/516...
# 1  https://www.autohero.com/fr/toyota-pro-ace/id/...
# 2  https://www.autohero.com/fr/mercedes-benz-gla/...
# 3  https://www.autohero.com/fr/bmw-x-1/id/490f203...
# 4  https://www.autohero.com/fr/peugeot-3008/id/df...

# %%
df.shape
# Out:
# (2352, 20)

# %% [markdown]
# Il y a 2352 lignes (annonces) et 22 colonnes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2352 entries, 0 to 2351
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   scraped_at                    2352 non-null   object
#  1   modele                        2342 non-null   object
#  2   finition                      2342 non-null   object
#  3   prix                          2342 non-null   object
#  4   annee_mise_en_circulation     2342 non-null   object
#  5   kilometrage                   2342 non-null   object
#  6   carburant                     2342 non-null   object
#  7   transmission                  2342 non-null   object
#  8   puissance                     2342 non-null   object
#  9   nb_ancien_proprietaire        2342 non-null   object
#  10  classe_vehicule               2342 non-null   object
#  11  nb_porte                      2342 non-null   float64
#  12  nb_place                      2342 non-null   float64
#  13  couleur                       2342 non-null   object
#  14  sellerie                      2342 non-null   object
#  15  classe_emission               2342 non-null   object
#  16  emission_CO2                  2086 non-null   object
#  17  crit_air                      2337 non-null   object
#  18  usage_commerciale_anterieure  2086 non-null   object
#  19  url_annonce                   2352 non-null   object
# dtypes: float64(2), object(18)
# memory usage: 367.6+ KB

# %% [markdown]
# ## 2. Pré transformation des données

# %%
# Convertir la colonne "prix" en float
# Supprimer les caractères indésirables et convertir en float
df["prix"] = (df["prix"]
              .str.replace("€", "")
              .str.replace("\u202f", "")
              .str.replace(" ", "")
              .str.replace(",", ".")
              .astype(float))

# Convertir la colonne "kilométrage" en float
# Supprimer les caractères indésirables et convertir en float
df["kilometrage"] = (df["kilometrage"]
                     .str.replace("km", "")
                     .str.replace("\u202f", "")
                     .str.replace(" ", "")
                     .astype(float))

# Extraire l'année de mise en circulation et la convertir en int
df["annee"] = (df["annee_mise_en_circulation"]
               .str.extract(r'(\d{4})')[0]
               .astype('Int64'))
                                   
# Convertir la colonne "puissance" en puissance_cv
# Extraire uniquement les chiffres avant "CV"
df["puissance"] = (df["puissance"]
                      .str.extract(r'(\d+) CV')[0]
                      .astype(float))

# Convertir la colonne "nb_porte" en int
df["nb_porte"] = df["nb_porte"].astype('Int64')

# Convertir la colonne "nb_place" en int
df["nb_place"] = df["nb_place"].astype('Int64')

# Extraire l'émission CO2 et la convertir en float
df["emission_CO2"] = (df["emission_CO2"]
                      .str.extract(r'(\d+) g/km')[0]
                      .astype(float))

# %%
df[df['prix'].isnull()]
# Out:
#       scraped_at modele finition  prix annee_mise_en_circulation  kilometrage  \
# 871   2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 1007  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 1082  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 1561  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 1752  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 1874  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 1942  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 2047  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 2158  2025-04-09    NaN      NaN   NaN                       NaN          NaN
# 2327  2025-04-09    NaN      NaN   NaN                       NaN          NaN
#
#      carburant transmission  puissance nb_ancien_proprietaire  ... nb_porte  \
# 871        NaN          NaN        NaN                    NaN  ...     <NA>
# 1007       NaN          NaN        NaN                    NaN  ...     <NA>
# 1082       NaN          NaN        NaN                    NaN  ...     <NA>
# 1561       NaN          NaN        NaN                    NaN  ...     <NA>
# 1752       NaN          NaN        NaN                    NaN  ...     <NA>
# 1874       NaN          NaN        NaN                    NaN  ...     <NA>
# 1942       NaN          NaN        NaN                    NaN  ...     <NA>
# 2047       NaN          NaN        NaN                    NaN  ...     <NA>
# 2158       NaN          NaN        NaN                    NaN  ...     <NA>
# 2327       NaN          NaN        NaN                    NaN  ...     <NA>
#
#       nb_place  couleur sellerie classe_emission emission_CO2  crit_air  \
# 871       <NA>      NaN      NaN             NaN          NaN       NaN
# 1007      <NA>      NaN      NaN             NaN          NaN       NaN
# 1082      <NA>      NaN      NaN             NaN          NaN       NaN
# 1561      <NA>      NaN      NaN             NaN          NaN       NaN
# 1752      <NA>      NaN      NaN             NaN          NaN       NaN
# 1874      <NA>      NaN      NaN             NaN          NaN       NaN
# 1942      <NA>      NaN      NaN             NaN          NaN       NaN
# 2047      <NA>      NaN      NaN             NaN          NaN       NaN
# 2158      <NA>      NaN      NaN             NaN          NaN       NaN
# 2327      <NA>      NaN      NaN             NaN          NaN       NaN
#
#      usage_commerciale_anterieure  \
# 871                           NaN
# 1007                          NaN
# 1082                          NaN
# 1561                          NaN
# 1752                          NaN
# 1874                          NaN
# 1942                          NaN
# 2047                          NaN
# 2158                          NaN
# 2327                          NaN
#
#                                             url_annonce annee
# 871   https://www.autohero.com/fr/bmw-serie-1/id/599...  <NA>
# 1007  https://www.autohero.com/fr/toyota-yaris/id/26...  <NA>
# 1082  https://www.autohero.com/fr/citroen-c-3/id/988...  <NA>
# 1561  https://www.autohero.com/fr/hyundai-tucson/id/...  <NA>
# 1752  https://www.autohero.com/fr/kia-x-ceed/id/0647...  <NA>
# 1874  https://www.autohero.com/fr/renault-captur/id/...  <NA>
# 1942  https://www.autohero.com/fr/hyundai-i-10/id/4d...  <NA>
# 2047  https://www.autohero.com/fr/renault-clio/id/e3...  <NA>
# 2158  https://www.autohero.com/fr/audi-q-2/id/a9a82f...  <NA>
# 2327  https://www.autohero.com/fr/volkswagen-golf-vi...  <NA>
#
# [10 rows x 21 columns]

# %%
# Calculer l'âge de la voiture:
df["age_days"] = (pd.to_datetime(df["scraped_at"]) -
                  pd.to_datetime(df["annee_mise_en_circulation"], dayfirst=True))
df["age_days"] = df["age_days"].apply(lambda x: x.days if pd.notnull(x) else None)

df["age_years"] = df["age_days"] / 365  # en années
df["age_years"] = df["age_years"].apply(lambda x: round(x, 1) if pd.notnull(x) else None)

# %%
# Extraire la marque de la voiture et l'insérer à côté de la colonne "modele"
# en utilisant la première partie de la chaîne avant l'espace
df.insert(df.columns.get_loc("modele"), "marque", df["modele"].str.split(" ").str[0])

# %%
observations_by_modele_annee = df.groupby(['modele', 'annee']).size().reset_index(name='count')
observations_by_modele_annee.sort_values(by= 'count', ascending = False)
# Out:
#                    modele  annee  count
# 557          Renault Clio   2019     34
# 498          Peugeot 2008   2020     33
# 497          Peugeot 2008   2019     28
# 508           Peugeot 208   2022     21
# 513          Peugeot 3008   2019     21
# ..                    ...    ...    ...
# 9    Alfa Romeo Giulietta   2017      1
# 8       Alfa Romeo Giulia   2021      1
# 7       Alfa Romeo Giulia   2020      1
# 6             Abarth 595C   2020      1
# 5              Abarth 595   2017      1
#
# [752 rows x 3 columns]

# %%
observations_by_modele = df.groupby(['modele']).size().reset_index(name='count')
observations_by_modele.sort_values(by= 'count', ascending = False)
# Out:
#                          modele  count
# 151                Peugeot 2008    115
# 163                Renault Clio    100
# 152                 Peugeot 208     88
# 153                Peugeot 3008     82
# 32                   Citroen C3     63
# ..                          ...    ...
# 197               Toyota ProAce      1
# 208           Volkswagen Passat      1
# 214  Volkswagen Tiguan Allspace      1
# 218     Volvo V40 Cross Country      1
# 220                  Volvo XC60      1
#
# [221 rows x 2 columns]

# %% [markdown]
# ## 3. Récupérer le prix neuf

# %%
# Importer la data des prix neufs
df_prix_neuf = pd.read_csv("../data/processed_data/prix_neuf_voitures_vf.csv", sep=",", encoding="utf-8")

# %%
df_prix_neuf
# Out:
#             source_model                                  Versions  Portes  \
# 0      Abarth 124 Spider                          II 1.4 TURBO 170     2.0
# 1      Abarth 124 Spider                       II 1.4 TURBO 170 GT     2.0
# 2      Abarth 124 Spider                   II 1.4 TURBO 170 GT BVA     2.0
# 3      Abarth 124 Spider                  II 1.4 TURBO 170 TURISMO     2.0
# 4      Abarth 124 Spider              II 1.4 TURBO 170 TURISMO BVA     2.0
# ...                  ...                                       ...     ...
# 56684            S-CROSS      1.4 BOOSTERJET HYBRID PRIVILEGE AUTO     5.0
# 56685            S-CROSS               1.4 BOOSTERJET HYBRID STYLE     5.0
# 56686            S-CROSS          1.4 BOOSTERJET HYBRID STYLE 2020     5.0
# 56687            S-CROSS       1.4 BOOSTERJET HYBRID STYLE ALLGRIP     5.0
# 56688            S-CROSS  1.4 BOOSTERJET HYBRID STYLE ALLGRIP AUTO     5.0
#
#       Energie        Boite CO2\n(g/km)      Prix  \
# 0        Ess.    Mécanique  146 (nedc)  34 500 €
# 1        Ess.    Mécanique  146 (nedc)  40 900 €
# 2        Ess.  Automatique  161 (nedc)  42 900 €
# 3        Ess.    Mécanique  146 (nedc)  37 500 €
# 4        Ess.  Automatique  161 (nedc)  39 500 €
# ...       ...          ...         ...       ...
# 56684    Ess.  Automatique  129 (wltp)  27 990 €
# 56685    Ess.    Mécanique  122 (wltp)  32 240 €
# 56686    Ess.    Mécanique  123 (wltp)  27 640 €
# 56687    Ess.    Mécanique  133 (wltp)  29 640 €
# 56688    Ess.  Automatique  142 (wltp)  31 340 €
#
#                                                      url option_marque_select  \
# 0      https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 1      https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 2      https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 3      https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 4      https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# ...                                                  ...                  ...
# 56684  https://www.caradisiac.com/fiches-techniques/m...               SUZUKI
# 56685  https://www.caradisiac.com/fiches-techniques/m...               SUZUKI
# 56686  https://www.caradisiac.com/fiches-techniques/m...               SUZUKI
# 56687  https://www.caradisiac.com/fiches-techniques/m...               SUZUKI
# 56688  https://www.caradisiac.com/fiches-techniques/m...               SUZUKI
#
#        option_year_select                 Version_selected
# 0                    2019  abarth 124 2e generation spider
# 1                    2019  abarth 124 2e generation spider
# 2                    2019  abarth 124 2e generation spider
# 3                    2019  abarth 124 2e generation spider
# 4                    2019  abarth 124 2e generation spider
# ...                   ...                              ...
# 56684                2021                   suzuki s cross
# 56685                2021                   suzuki s cross
# 56686                2021                   suzuki s cross
# 56687                2021                   suzuki s cross
# 56688                2021                   suzuki s cross
#
# [56689 rows x 11 columns]

# %%
df_prix_neuf[(df_prix_neuf['source_model'].str.contains("Fiat 500X")) & (df_prix_neuf["option_year_select"]==2017)]
# Out:
#      source_model                                           Versions  Portes  \
# 9094    Fiat 500X         II (2) 0.9 8V 105 TWINAIR S/S ANNIVERSARIO     3.0
# 9095    Fiat 500X                 II (2) 0.9 8V 105 TWINAIR S/S CLUB     3.0
# 9096    Fiat 500X               II (2) 0.9 8V 105 TWINAIR S/S LOUNGE     3.0
# 9097    Fiat 500X                 II (2) 0.9 8V 105 TWINAIR S/S RIVA     3.0
# 9098    Fiat 500X  II (2) 0.9 8V 105 TWINAIR S/S RIVA AVEC VOLANT...     3.0
# ...           ...                                                ...     ...
# 9269    Fiat 500X           II (2) C 1.3 16V 95 MULTIJET S/S POPSTAR     2.0
# 9270    Fiat 500X              II (2) C 1.3 16V 95 MULTIJET S/S RIVA     2.0
# 9271    Fiat 500X  II (2) C 1.3 16V 95 MULTIJET S/S RIVA AVEC VOL...     2.0
# 9272    Fiat 500X                 II (2) C 1.3 16V 95 MULTIJET S/S S     2.0
# 9273    Fiat 500X            II (2) C 1.3 16V 95 MULTIJET S/S S PLUS     2.0
#
#      Energie      Boite CO2\n(g/km)      Prix  \
# 9094    Ess.  Mécanique   99 (nedc)  18 190 €
# 9095    Ess.  Mécanique   99 (nedc)  19 390 €
# 9096    Ess.  Mécanique   99 (nedc)  17 890 €
# 9097    Ess.  Mécanique   99 (nedc)  20 890 €
# 9098    Ess.  Mécanique   99 (nedc)  21 740 €
# ...      ...        ...         ...       ...
# 9269   Dies.  Mécanique   89 (nedc)  20 140 €
# 9270   Dies.  Mécanique   89 (nedc)  24 040 €
# 9271   Dies.  Mécanique   89 (nedc)  24 890 €
# 9272   Dies.  Mécanique   89 (nedc)  21 840 €
# 9273   Dies.  Mécanique   89 (nedc)  23 340 €
#
#                                                     url option_marque_select  \
# 9094  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9095  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9096  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9097  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9098  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# ...                                                 ...                  ...
# 9269  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9270  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9271  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9272  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
# 9273  https://www.caradisiac.com/fiches-techniques/m...                 FIAT
#
#       option_year_select        Version_selected
# 9094                2017  fiat 500 2e generation
# 9095                2017  fiat 500 2e generation
# 9096                2017  fiat 500 2e generation
# 9097                2017  fiat 500 2e generation
# 9098                2017  fiat 500 2e generation
# ...                  ...                     ...
# 9269                2017              fiat 500 c
# 9270                2017              fiat 500 c
# 9271                2017              fiat 500 c
# 9272                2017              fiat 500 c
# 9273                2017              fiat 500 c
#
# [180 rows x 11 columns]

# %%
# Rename "marque" to match with the right name used in the caradisiac website (df_prix_neuf)
# Create a dictionary to map the names of the brands in df to the names used in df_prix_neuf
dict_name_marque = {'Abarth' : 'Abarth', 'Alfa' : 'Alfa Romeo', 'Audi' : 'Audi', 
                    'BMW' : 'BMW', 
                    'Citroen' : 'Citroen', 'Cupra' : 'Cupra', 
                    'DS' : 'DS', 'Dacia' : 'Dacia',
                    'Fiat' : 'Fiat', 'Ford' : 'Ford', 
                    'Honda' : 'Honda', 'Hyundai' : 'Hyundai', 
                    'Infiniti' : 'Infiniti', 
                    'Jaguar' : 'Jaguar', 'Jeep' : 'Jeep',
                    'Kia' : 'Kia', 
                    'Land' : 'Land Rover', 'Lexus' : 'Lexus', 
                    'MG' : "MG", 'MINI' : 'MINI', 'Mazda' : 'Mazda', 'Mercedes-Benz' : 'Mercedes', 'Mitsubishi' : 'Mitsubishi', 
                    'Nissan' : 'Nissan', 
                    'Opel' : 'Opel', 
                    'Peugeot' : 'Peugeot', 
                    'Renault' : 'Renault', 
                    'Seat' : 'Seat', 'Skoda' : 'Skoda', 'Smart' : 'Smart', 'Suzuki' : 'Suzuki', 
                    'Toyota' : 'Toyota', 
                    'Volkswagen' : 'Volkswagen', 'Volvo' : 'Volvo'
                    }

# Replace the names in the "marque" column of df with the corresponding names in df_prix_neuf
# using the dictionary created above
df['marque'] = df['marque'].replace(dict_name_marque)

# %%
# Rename "marque" Citroen = DS if "modele" contains DS and "marque" contains Citroen
df.loc[(df['marque'].str.lower().str.contains('citroen', na=False)) & (df['modele'].str.lower().str.contains('ds', na=False)), "marque"] = "DS"

# %%
# Checking again, should be empty
df[(df['modele'].str.lower().str.contains("ds", na=False)) & (df['marque'].str.lower().str.contains('citroen', na=False))]
# Out:
# Empty DataFrame
# Columns: [scraped_at, marque, modele, finition, prix, annee_mise_en_circulation, kilometrage, carburant, transmission, puissance, nb_ancien_proprietaire, classe_vehicule, nb_porte, nb_place, couleur, sellerie, classe_emission, emission_CO2, crit_air, usage_commerciale_anterieure, url_annonce, annee, age_days, age_years]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Corriger manuellement le nom du modèle/marque pour qu'il soit aligné avec celui utilisé par le site caradisiac
# Créer un dictionnaire pour mapper les noms de modèles dans df à ceux utilisés dans df_prix_neuf
dict_model_corr = {
 'Abarth 595' : '500',
 'Abarth 595C' : '500',
 'Citroen C4 Grand Picasso' : 'C4 PICASSO',
 'Citroen C4 Picasso' : 'C4 PICASSO', 
 'Citroen DS3' : 'DS3',
 'Citroen DS3 Cabrio' : 'DS3',
 'Citroen DS4' : 'DS4',
 'Citroen DS4 Crossback' : 'DS4 CROSSBACK',
 'Citroen DS5' : 'DS5',
 'Ford Ka+' : 'KA+',
 'Ford Tourneo' : 'TOURNEO COURIER',
 "Kia cee'd" : 'CEED',
 "Kia pro_cee'd": 'PROCEED',
 'Land Rover Evoque' : 'RANGE ROVER EVOQUE',
 'Mercedes-Benz Classe GLB' : 'GLB',
 'Mercedes-Benz Classe GLC' : 'GLC',
 'Mercedes-Benz Classe GLE' : 'GLE',
 'Opel Crossland X' : 'CROSSLAND' ,
 'Suzuki SX4 S-Cross' : 'S-CROSS'
}

# %%
# Replace the "modele" name
df['modele'] = df['modele'].replace(dict_model_corr)

# %%
# Homogénéiser le format des colonnes pour les deux DataFrames
df['marque'] = df['marque'].str.upper()
df['finition'] = df['finition'].str.upper()
df['modele'] = df['modele'].str.upper()
df['puissance'] = df['puissance'].astype('Int64')

df_prix_neuf['option_marque_select'] = df_prix_neuf['option_marque_select'].str.upper()
df_prix_neuf['Versions'] = df_prix_neuf['Versions'].str.upper()
df_prix_neuf['source_model'] = df_prix_neuf['source_model'].str.upper()
df_prix_neuf['Version_selected'] = df_prix_neuf['Version_selected'].str.upper()
df_prix_neuf['Portes'] = df_prix_neuf['Portes'].astype('Int64')
df_prix_neuf['option_year_select'] = df_prix_neuf['option_year_select'].astype('Int64')

# Rename columns
df_prix_neuf.rename(columns={"Prix": "prix_neuf", "url" : 'url_prix_neuf'}, inplace=True)

# Homogénéiser le type de boite de vitesse
dict_boite = {'Double embrayage / DCT' : 'Boite de vitesse automatique',
              'Semi-automatique' : 'Boite de vitesse automatique',
              'Automatique': 'Boite de vitesse automatique',
              'Mécanique': 'Boite de vitesse manuelle'
              }
df_prix_neuf['Boite'] = df_prix_neuf['Boite'].replace(dict_boite)
df['transmission'] = df['transmission'].replace(dict_boite)

# %%
df_prix_neuf.head()
# Out:
#         source_model                      Versions  Portes Energie  \
# 0  ABARTH 124 SPIDER              II 1.4 TURBO 170       2    Ess.
# 1  ABARTH 124 SPIDER           II 1.4 TURBO 170 GT       2    Ess.
# 2  ABARTH 124 SPIDER       II 1.4 TURBO 170 GT BVA       2    Ess.
# 3  ABARTH 124 SPIDER      II 1.4 TURBO 170 TURISMO       2    Ess.
# 4  ABARTH 124 SPIDER  II 1.4 TURBO 170 TURISMO BVA       2    Ess.
#
#                           Boite CO2\n(g/km) prix_neuf  \
# 0     Boite de vitesse manuelle  146 (nedc)  34 500 €
# 1     Boite de vitesse manuelle  146 (nedc)  40 900 €
# 2  Boite de vitesse automatique  161 (nedc)  42 900 €
# 3     Boite de vitesse manuelle  146 (nedc)  37 500 €
# 4  Boite de vitesse automatique  161 (nedc)  39 500 €
#
#                                        url_prix_neuf option_marque_select  \
# 0  https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 1  https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 2  https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 3  https://www.caradisiac.com/fiches-techniques/m...               ABARTH
# 4  https://www.caradisiac.com/fiches-techniques/m...               ABARTH
#
#    option_year_select                 Version_selected
# 0                2019  ABARTH 124 2E GENERATION SPIDER
# 1                2019  ABARTH 124 2E GENERATION SPIDER
# 2                2019  ABARTH 124 2E GENERATION SPIDER
# 3                2019  ABARTH 124 2E GENERATION SPIDER
# 4                2019  ABARTH 124 2E GENERATION SPIDER

# %%
df_prix_neuf[df_prix_neuf['prix_neuf'] == "NC"]
# Out:
#       source_model                          Versions  Portes Energie  \
# 16935        MG ZS                        ELECTRIQUE       5   Elec.
# 18716    MINI MINI  III (F55) 1.5 136 COOPER BVA6 5P       5    Ess.
# 18905    MINI MINI  III (F55) 1.5 136 COOPER BVA6 5P       5    Ess.
# 19173    MINI MINI  III (F55) 1.5 136 COOPER BVA6 5P       5    Ess.
# 30348  PEUGEOT 308        1.6 THP 140 PREMIUM BVA 3P       3    Ess.
#
#                               Boite CO2\n(g/km) prix_neuf  \
# 16935  Boite de vitesse automatique          NC        NC
# 18716  Boite de vitesse automatique          NC        NC
# 18905  Boite de vitesse automatique          NC        NC
# 19173  Boite de vitesse automatique          NC        NC
# 30348  Boite de vitesse automatique          NC        NC
#
#                                            url_prix_neuf option_marque_select  \
# 16935  https://www.caradisiac.com/fiches-techniques/m...                   MG
# 18716  https://www.caradisiac.com/fiches-techniques/m...                 MINI
# 18905  https://www.caradisiac.com/fiches-techniques/m...                 MINI
# 19173  https://www.caradisiac.com/fiches-techniques/m...                 MINI
# 30348  https://www.caradisiac.com/fiches-techniques/m...              PEUGEOT
#
#        option_year_select Version_selected
# 16935                2022         MG MG ZS
# 18716                2019   MINI MINI 3 5P
# 18905                2020   MINI MINI 3 5P
# 19173                2021   MINI MINI 3 5P
# 30348                2023      PEUGEOT 308

# %%
# 1. Merging df with df_prix_neuf to get the listing price. Keys: marque, modele, annee
df_merge_1 = df.merge(df_prix_neuf, how="left", left_on=['marque', 'modele', 'annee'], right_on = ['option_marque_select', 'source_model', 'option_year_select'] )

# %%
df.head()
# Out:
#    scraped_at    marque             modele                     finition  \
# 0  2025-04-09      FORD        FORD FIESTA       1.0 ECOBOOST ST-LINE X
# 1  2025-04-09    TOYOTA      TOYOTA PROACE  COMBI LONG 1.5 D-4D DYNAMIC
# 2  2025-04-09  MERCEDES  MERCEDES-BENZ GLA        250 E AMG LINE 8G-DCT
# 3  2025-04-09       BMW             BMW X1         SDRIVE18I XLINE DKG7
# 4  2025-04-09   PEUGEOT       PEUGEOT 3008   1.5 BLUE-HDI CROSSWAY EAT8
#
#       prix annee_mise_en_circulation  kilometrage carburant  \
# 0  13190.0                15.05.2020      69301.0   Essence
# 1  23990.0                29.04.2021      71887.0    Diesel
# 2  32490.0                23.10.2020      59649.0   Hybride
# 3  27890.0                05.05.2021      37869.0   Essence
# 4  19090.0                31.12.2019      58958.0    Diesel
#
#                    transmission  puissance  ... couleur  \
# 0     Boite de vitesse manuelle         95  ...    Gris
# 1     Boite de vitesse manuelle        120  ...    Gris
# 2  Boite de vitesse automatique        218  ...    Gris
# 3  Boite de vitesse automatique        136  ...    Noir
# 4  Boite de vitesse automatique        130  ...   Blanc
#
#                        sellerie  classe_emission  emission_CO2    crit_air  \
# 0    Tissu (Sellerie d'origine)           EURO 6           NaN  Crit'Air 1
# 1    Tissu (Sellerie d'origine)           EURO 6         170.0  Crit'Air 2
# 2  Mi-cuir (Sellerie d'origine)           EURO 6          32.0  Crit'Air 1
# 3  Mi-cuir (Sellerie d'origine)           EURO 6         148.0  Crit'Air 1
# 4  Mi-cuir (Sellerie d'origine)           EURO 6          98.0  Crit'Air 2
#
#   usage_commerciale_anterieure  \
# 0                          NaN
# 1                          Oui
# 2                          Oui
# 3                          Non
# 4                          Oui
#
#                                          url_annonce  annee age_days age_years
# 0  https://www.autohero.com/fr/ford-fiesta/id/516...   2020   1790.0       4.9
# 1  https://www.autohero.com/fr/toyota-pro-ace/id/...   2021   1441.0       3.9
# 2  https://www.autohero.com/fr/mercedes-benz-gla/...   2020   1629.0       4.5
# 3  https://www.autohero.com/fr/bmw-x-1/id/490f203...   2021   1435.0       3.9
# 4  https://www.autohero.com/fr/peugeot-3008/id/df...   2019   1926.0       5.3
#
# [5 rows x 24 columns]

# %%
# Concaténer puissance avec la finition
df_merge_1['finition_puiss'] = df_merge_1['finition'].astype(str) + " " + df_merge_1['puissance'].astype(str) + " CV"

# Concaténer "Versions" avec "Version_selected"
df_merge_1['Version_finale'] = df_merge_1['Version_selected'].astype(str) + " " + df_merge_1['Versions'].astype(str)

# %%
df_merge_1
# Out:
#         scraped_at   marque          modele                finition     prix  \
# 0       2025-04-09     FORD     FORD FIESTA  1.0 ECOBOOST ST-LINE X  13190.0
# 1       2025-04-09     FORD     FORD FIESTA  1.0 ECOBOOST ST-LINE X  13190.0
# 2       2025-04-09     FORD     FORD FIESTA  1.0 ECOBOOST ST-LINE X  13190.0
# 3       2025-04-09     FORD     FORD FIESTA  1.0 ECOBOOST ST-LINE X  13190.0
# 4       2025-04-09     FORD     FORD FIESTA  1.0 ECOBOOST ST-LINE X  13190.0
# ...            ...      ...             ...                     ...      ...
# 189591  2025-04-09  RENAULT  RENAULT SCENIC      1.3 TCE SL LIMITED  19990.0
# 189592  2025-04-09  RENAULT  RENAULT SCENIC      1.3 TCE SL LIMITED  19990.0
# 189593  2025-04-09  RENAULT  RENAULT SCENIC      1.3 TCE SL LIMITED  19990.0
# 189594  2025-04-09  RENAULT  RENAULT SCENIC      1.3 TCE SL LIMITED  19990.0
# 189595  2025-04-09  RENAULT  RENAULT SCENIC      1.3 TCE SL LIMITED  19990.0
#
#        annee_mise_en_circulation  kilometrage carburant  \
# 0                     15.05.2020      69301.0   Essence
# 1                     15.05.2020      69301.0   Essence
# 2                     15.05.2020      69301.0   Essence
# 3                     15.05.2020      69301.0   Essence
# 4                     15.05.2020      69301.0   Essence
# ...                          ...          ...       ...
# 189591                20.04.2021       6321.0   Essence
# 189592                20.04.2021       6321.0   Essence
# 189593                20.04.2021       6321.0   Essence
# 189594                20.04.2021       6321.0   Essence
# 189595                20.04.2021       6321.0   Essence
#
#                      transmission  puissance  ... Energie  \
# 0       Boite de vitesse manuelle         95  ...    Ess.
# 1       Boite de vitesse manuelle         95  ...    Ess.
# 2       Boite de vitesse manuelle         95  ...    Ess.
# 3       Boite de vitesse manuelle         95  ...    Ess.
# 4       Boite de vitesse manuelle         95  ...    Ess.
# ...                           ...        ...  ...     ...
# 189591  Boite de vitesse manuelle        140  ...   Dies.
# 189592  Boite de vitesse manuelle        140  ...   Dies.
# 189593  Boite de vitesse manuelle        140  ...   Dies.
# 189594  Boite de vitesse manuelle        140  ...   Dies.
# 189595  Boite de vitesse manuelle        140  ...   Dies.
#
#                                Boite  CO2\n(g/km)  prix_neuf  \
# 0          Boite de vitesse manuelle   114 (wltp)   22 790 €
# 1          Boite de vitesse manuelle   114 (wltp)   23 890 €
# 2       Boite de vitesse automatique   149 (wltp)   21 100 €
# 3       Boite de vitesse automatique   149 (wltp)   20 600 €
# 4       Boite de vitesse automatique   150 (wltp)   21 650 €
# ...                              ...          ...        ...
# 189591     Boite de vitesse manuelle   141 (wltp)   37 300 €
# 189592  Boite de vitesse automatique   153 (wltp)   39 300 €
# 189593  Boite de vitesse automatique   156 (wltp)   37 300 €
# 189594     Boite de vitesse manuelle   153 (wltp)   33 300 €
# 189595  Boite de vitesse automatique   156 (wltp)   35 300 €
#
#                                             url_prix_neuf  \
# 0       https://www.caradisiac.com/fiches-techniques/m...
# 1       https://www.caradisiac.com/fiches-techniques/m...
# 2       https://www.caradisiac.com/fiches-techniques/m...
# 3       https://www.caradisiac.com/fiches-techniques/m...
# 4       https://www.caradisiac.com/fiches-techniques/m...
# ...                                                   ...
# 189591  https://www.caradisiac.com/fiches-techniques/m...
# 189592  https://www.caradisiac.com/fiches-techniques/m...
# 189593  https://www.caradisiac.com/fiches-techniques/m...
# 189594  https://www.caradisiac.com/fiches-techniques/m...
# 189595  https://www.caradisiac.com/fiches-techniques/m...
#
#        option_marque_select option_year_select  Version_selected  \
# 0                      FORD               2020     FORD FIESTA 6
# 1                      FORD               2020     FORD FIESTA 6
# 2                      FORD               2020     FORD FIESTA 6
# 3                      FORD               2020     FORD FIESTA 6
# 4                      FORD               2020     FORD FIESTA 6
# ...                     ...                ...               ...
# 189591              RENAULT               2021  RENAULT SCENIC 4
# 189592              RENAULT               2021  RENAULT SCENIC 4
# 189593              RENAULT               2021  RENAULT SCENIC 4
# 189594              RENAULT               2021  RENAULT SCENIC 4
# 189595              RENAULT               2021  RENAULT SCENIC 4
#
#                       finition_puiss  \
# 0       1.0 ECOBOOST ST-LINE X 95 CV
# 1       1.0 ECOBOOST ST-LINE X 95 CV
# 2       1.0 ECOBOOST ST-LINE X 95 CV
# 3       1.0 ECOBOOST ST-LINE X 95 CV
# 4       1.0 ECOBOOST ST-LINE X 95 CV
# ...                              ...
# 189591     1.3 TCE SL LIMITED 140 CV
# 189592     1.3 TCE SL LIMITED 140 CV
# 189593     1.3 TCE SL LIMITED 140 CV
# 189594     1.3 TCE SL LIMITED 140 CV
# 189595     1.3 TCE SL LIMITED 140 CV
#
#                                            Version_finale
# 0       FORD FIESTA 6 VI (2) 1.0 ECOBOOST 125 MHEV ST-...
# 1       FORD FIESTA 6 VI (2) 1.0 ECOBOOST 125 MHEV ST-...
# 2       FORD FIESTA 6 VI 1.0 ECOBOOST 100 5CV CONNECT ...
# 3       FORD FIESTA 6 VI 1.0 ECOBOOST 100 5CV S&S CONN...
# 4       FORD FIESTA 6 VI 1.0 ECOBOOST 100 5CV S&S TITA...
# ...                                                   ...
# 189591  RENAULT SCENIC 4 IV 1.7 DCI 150 8CV BLUE SL BL...
# 189592  RENAULT SCENIC 4 IV 1.7 DCI 150 8CV BLUE SL BL...
# 189593  RENAULT SCENIC 4 IV 1.7 DCI 150 BLUE INTENS BL...
# 189594           RENAULT SCENIC 4 IV 1.7 DCI 150 BUSINESS
# 189595       RENAULT SCENIC 4 IV 1.7 DCI 150 BUSINESS EDC
#
# [189596 rows x 37 columns]

# %%
# 2. Sélectionner les versions les plus proches du cible
# Création d'un système de notation pour évaluer la proximité entre les versions
# finition_puiss & Versions, transmission & Boite, nb_porte vs Portes

# Calculer le score de proximité entre la finition_puissance et Version_finale
df_merge_1['note_version_commune'] = df_merge_1.apply(
	lambda x: len(set(x['finition_puiss'].split()) & set(x['Version_finale'].split())) if pd.notnull(x['finition_puiss']) and pd.notnull(x['Version_finale']) else 0,
	axis=1
)

# Calculer le score de proximité entre la transmission et Boite
df_merge_1['note_transmission_commune'] = df_merge_1.apply(
	lambda x: 1 if pd.notnull(x['transmission']) and pd.notnull(x['Boite']) and x['transmission'] == x['Boite'] else 0,
	axis=1
)

# Calculer le score de proximité entre le nombre de portes et Portes
df_merge_1['note_nb_porte_commune'] = df_merge_1.apply(
	lambda x: 1 if pd.notnull(x['nb_porte']) and pd.notnull(x['Portes']) and x['nb_porte'] == x['Portes'] else 0,
	axis=1
)

# Calculer le score total
df_merge_1['note_commune_total'] = df_merge_1['note_version_commune'] +df_merge_1['note_transmission_commune'] + df_merge_1['note_nb_porte_commune']

# %%
# Garder les lignes avec les scores les plus élevés pour chaque combinaison de marque, modele et annee
df_merge_1['max_note'] = df_merge_1.groupby(['marque', 'modele', 'annee'])['note_commune_total'].transform('max')
df_merge_2 = df_merge_1[df_merge_1['note_commune_total'] == df_merge_1['max_note']]
df_merge_2.sort_values(by=['marque', 'modele', 'annee'], ascending=[True, True, True], inplace=True)
df_merge_2.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\Hong-CuongLE\AppData\Local\Temp\ipykernel_18484\3568166748.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_2.sort_values(by=['marque', 'modele', 'annee'], ascending=[True, True, True], inplace=True)

# %%
df_merge_2.shape
# Out:
# (2880, 42)

# %%
df_merge_2[df_merge_2['note_commune_total']== 0]
# Out:
#       scraped_at   marque      modele                         finition  \
# 359   2025-04-09  CITROEN  C4 PICASSO       (2) 1.2 PURETECH SHINE BV6
# 360   2025-04-09  CITROEN  C4 PICASSO        (2) 1.2 PURETECH FEEL BV6
# 361   2025-04-09  CITROEN  C4 PICASSO       (2) 1.2 PURETECH SHINE BV6
# 362   2025-04-09  CITROEN  C4 PICASSO      (2) 1.2 PURETECH SHINE EAT6
# 363   2025-04-09  CITROEN  C4 PICASSO           1.2 PURETECH SHINE BV6
# 1165  2025-04-09     FORD         KA+             1.2 TI-VCT ESSENTIAL
# 1380  2025-04-09      KIA     PROCEED        1.0 T-GDI ISG GT-LINE BV6
# 1749  2025-04-09     OPEL   CROSSLAND        1.2 TURBO INNOVATION AUTO
# 1750  2025-04-09     OPEL   CROSSLAND             1.2 TURBO INNOVATION
# 1751  2025-04-09     OPEL   CROSSLAND   1.2 TURBO ULTIMATE AUTOMATIQUE
# 1752  2025-04-09     OPEL   CROSSLAND             1.2 TURBO INNOVATION
# 1753  2025-04-09     OPEL   CROSSLAND             1.2 TURBO INNOVATION
# 1754  2025-04-09     OPEL   CROSSLAND             1.2 TURBO INNOVATION
# 1755  2025-04-09     OPEL   CROSSLAND               1.2 TURBO ULTIMATE
# 1756  2025-04-09     OPEL   CROSSLAND               1.2 TURBO ULTIMATE
# 1757  2025-04-09     OPEL   CROSSLAND    1.2 TURBO DESIGN 120 ANS AUTO
# 1758  2025-04-09     OPEL   CROSSLAND         1.2 TURBO DESIGN 120 ANS
# 1759  2025-04-09     OPEL   CROSSLAND         1.2 TURBO DESIGN 120 ANS
# 1760  2025-04-09     OPEL   CROSSLAND         1.2 TURBO DESIGN 120 ANS
# 1761  2025-04-09     OPEL   CROSSLAND     1.5 DIESEL ELEGANCE BUSINESS
# 1762  2025-04-09     OPEL   CROSSLAND     1.5 DIESEL ELEGANCE BUSINESS
# 1763  2025-04-09     OPEL   CROSSLAND               1.2 TURBO ELEGANCE
# 1764  2025-04-09     OPEL   CROSSLAND  1.5 DIESEL ELEGANCE AUTOMATIQUE
# 1765  2025-04-09     OPEL   CROSSLAND      1.2 TURBO ELEGANCE BUSINESS
# 1766  2025-04-09     OPEL   CROSSLAND  1.5 DIESEL ELEGANCE AUTOMATIQUE
# 1767  2025-04-09     OPEL   CROSSLAND     1.5 DIESEL ELEGANCE BUSINESS
# 2502  2025-04-09   SUZUKI     S-CROSS      1.4 BOOSTERJET HYBRID STYLE
#
#          prix annee_mise_en_circulation  kilometrage carburant  \
# 359   10690.0                17.01.2018      87749.0   Essence
# 360   10790.0                19.11.2018      44552.0   Essence
# 361   10690.0                17.01.2018      87749.0   Essence
# 362   11690.0                24.04.2019      65767.0   Essence
# 363   10590.0                31.05.2019      87702.0   Essence
# 1165   7390.0                20.12.2017      77468.0   Essence
# 1380  10790.0                16.03.2017      84553.0   Essence
# 1749  10890.0                24.08.2017      83454.0   Essence
# 1750  11390.0                06.08.2018      61644.0   Essence
# 1751  12590.0                30.04.2018      57620.0   Essence
# 1752  10490.0                14.02.2018      53391.0   Essence
# 1753  11390.0                06.08.2018      61644.0   Essence
# 1754  10290.0                17.09.2018      70943.0   Essence
# 1755  10390.0                09.05.2018      77560.0   Essence
# 1756  10390.0                09.05.2018      77560.0   Essence
# 1757  11590.0                20.05.2019      82986.0   Essence
# 1758  10090.0                29.11.2019      73916.0   Essence
# 1759  10490.0                25.03.2019      92651.0   Essence
# 1760  10490.0                25.03.2019      92651.0   Essence
# 1761  12590.0                29.09.2020      64917.0    Diesel
# 1762  12590.0                29.09.2020      64917.0    Diesel
# 1763  12890.0                30.12.2021      42257.0   Essence
# 1764  13590.0                29.10.2021      88266.0    Diesel
# 1765  12390.0                16.04.2021      60091.0   Essence
# 1766  15890.0                31.05.2021      49601.0    Diesel
# 1767  14890.0                11.02.2021      41859.0    Diesel
# 2502  16590.0                05.03.2020      37465.0   Essence
#
#                       transmission  puissance  ... option_marque_select  \
# 359      Boite de vitesse manuelle        130  ...                  NaN
# 360      Boite de vitesse manuelle        130  ...                  NaN
# 361      Boite de vitesse manuelle        130  ...                  NaN
# 362   Boite de vitesse automatique        130  ...                  NaN
# 363      Boite de vitesse manuelle        130  ...                  NaN
# 1165     Boite de vitesse manuelle         70  ...                  NaN
# 1380     Boite de vitesse manuelle        120  ...                  NaN
# 1749  Boite de vitesse automatique        110  ...                  NaN
# 1750     Boite de vitesse manuelle        110  ...                  NaN
# 1751  Boite de vitesse automatique        110  ...                  NaN
# 1752     Boite de vitesse manuelle        110  ...                  NaN
# 1753     Boite de vitesse manuelle        110  ...                  NaN
# 1754     Boite de vitesse manuelle        130  ...                  NaN
# 1755     Boite de vitesse manuelle        130  ...                  NaN
# 1756     Boite de vitesse manuelle        130  ...                  NaN
# 1757  Boite de vitesse automatique        110  ...                  NaN
# 1758     Boite de vitesse manuelle        110  ...                  NaN
# 1759     Boite de vitesse manuelle        110  ...                  NaN
# 1760     Boite de vitesse manuelle        110  ...                  NaN
# 1761     Boite de vitesse manuelle        102  ...                  NaN
# 1762     Boite de vitesse manuelle        102  ...                  NaN
# 1763     Boite de vitesse manuelle        110  ...                  NaN
# 1764  Boite de vitesse automatique        120  ...                  NaN
# 1765     Boite de vitesse manuelle        110  ...                  NaN
# 1766  Boite de vitesse automatique        120  ...                  NaN
# 1767     Boite de vitesse manuelle        102  ...                  NaN
# 2502     Boite de vitesse manuelle        129  ...                  NaN
#
#      option_year_select  Version_selected  \
# 359                <NA>               NaN
# 360                <NA>               NaN
# 361                <NA>               NaN
# 362                <NA>               NaN
# 363                <NA>               NaN
# 1165               <NA>               NaN
# 1380               <NA>               NaN
# 1749               <NA>               NaN
# 1750               <NA>               NaN
# 1751               <NA>               NaN
# 1752               <NA>               NaN
# 1753               <NA>               NaN
# 1754               <NA>               NaN
# 1755               <NA>               NaN
# 1756               <NA>               NaN
# 1757               <NA>               NaN
# 1758               <NA>               NaN
# 1759               <NA>               NaN
# 1760               <NA>               NaN
# 1761               <NA>               NaN
# 1762               <NA>               NaN
# 1763               <NA>               NaN
# 1764               <NA>               NaN
# 1765               <NA>               NaN
# 1766               <NA>               NaN
# 1767               <NA>               NaN
# 2502               <NA>               NaN
#
#                               finition_puiss Version_finale  \
# 359        (2) 1.2 PURETECH SHINE BV6 130 CV        nan nan
# 360         (2) 1.2 PURETECH FEEL BV6 130 CV        nan nan
# 361        (2) 1.2 PURETECH SHINE BV6 130 CV        nan nan
# 362       (2) 1.2 PURETECH SHINE EAT6 130 CV        nan nan
# 363            1.2 PURETECH SHINE BV6 130 CV        nan nan
# 1165              1.2 TI-VCT ESSENTIAL 70 CV        nan nan
# 1380        1.0 T-GDI ISG GT-LINE BV6 120 CV        nan nan
# 1749        1.2 TURBO INNOVATION AUTO 110 CV        nan nan
# 1750             1.2 TURBO INNOVATION 110 CV        nan nan
# 1751   1.2 TURBO ULTIMATE AUTOMATIQUE 110 CV        nan nan
# 1752             1.2 TURBO INNOVATION 110 CV        nan nan
# 1753             1.2 TURBO INNOVATION 110 CV        nan nan
# 1754             1.2 TURBO INNOVATION 130 CV        nan nan
# 1755               1.2 TURBO ULTIMATE 130 CV        nan nan
# 1756               1.2 TURBO ULTIMATE 130 CV        nan nan
# 1757    1.2 TURBO DESIGN 120 ANS AUTO 110 CV        nan nan
# 1758         1.2 TURBO DESIGN 120 ANS 110 CV        nan nan
# 1759         1.2 TURBO DESIGN 120 ANS 110 CV        nan nan
# 1760         1.2 TURBO DESIGN 120 ANS 110 CV        nan nan
# 1761     1.5 DIESEL ELEGANCE BUSINESS 102 CV        nan nan
# 1762     1.5 DIESEL ELEGANCE BUSINESS 102 CV        nan nan
# 1763               1.2 TURBO ELEGANCE 110 CV        nan nan
# 1764  1.5 DIESEL ELEGANCE AUTOMATIQUE 120 CV        nan nan
# 1765      1.2 TURBO ELEGANCE BUSINESS 110 CV        nan nan
# 1766  1.5 DIESEL ELEGANCE AUTOMATIQUE 120 CV        nan nan
# 1767     1.5 DIESEL ELEGANCE BUSINESS 102 CV        nan nan
# 2502      1.4 BOOSTERJET HYBRID STYLE 129 CV        nan nan
#
#      note_version_commune note_transmission_commune  note_nb_porte_commune  \
# 359                     0                         0                      0
# 360                     0                         0                      0
# 361                     0                         0                      0
# 362                     0                         0                      0
# 363                     0                         0                      0
# 1165                    0                         0                      0
# 1380                    0                         0                      0
# 1749                    0                         0                      0
# 1750                    0                         0                      0
# 1751                    0                         0                      0
# 1752                    0                         0                      0
# 1753                    0                         0                      0
# 1754                    0                         0                      0
# 1755                    0                         0                      0
# 1756                    0                         0                      0
# 1757                    0                         0                      0
# 1758                    0                         0                      0
# 1759                    0                         0                      0
# 1760                    0                         0                      0
# 1761                    0                         0                      0
# 1762                    0                         0                      0
# 1763                    0                         0                      0
# 1764                    0                         0                      0
# 1765                    0                         0                      0
# 1766                    0                         0                      0
# 1767                    0                         0                      0
# 2502                    0                         0                      0
#
#      note_commune_total max_note
# 359                   0      0.0
# 360                   0      0.0
# 361                   0      0.0
# 362                   0      0.0
# 363                   0      0.0
# 1165                  0      0.0
# 1380                  0      0.0
# 1749                  0      0.0
# 1750                  0      0.0
# 1751                  0      0.0
# 1752                  0      0.0
# 1753                  0      0.0
# 1754                  0      0.0
# 1755                  0      0.0
# 1756                  0      0.0
# 1757                  0      0.0
# 1758                  0      0.0
# 1759                  0      0.0
# 1760                  0      0.0
# 1761                  0      0.0
# 1762                  0      0.0
# 1763                  0      0.0
# 1764                  0      0.0
# 1765                  0      0.0
# 1766                  0      0.0
# 1767                  0      0.0
# 2502                  0      0.0
#
# [27 rows x 42 columns]

# %%
df_prix_neuf[(df_prix_neuf['source_model'].str.contains("KA+", na=False))]
# Out:
#       source_model            Versions  Portes Energie  \
# 12414     FORD KA+      1.3 COLLECTION       3    Ess.
# 12415     FORD KA+          1.3 ELANCE       3    Ess.
# 12416     FORD KA+       1.3 OBSESSION       3    Ess.
# 12417     FORD KA+  1.3 OBSESSION PACK       3    Ess.
# 12418     FORD KA+        1.3 ORIGINAL       3    Ess.
# ...            ...                 ...     ...     ...
# 54959          KA+      1.3 COLLECTION       3    Ess.
# 54960          KA+          1.3 ELANCE       3    Ess.
# 54961          KA+       1.3 OBSESSION       3    Ess.
# 54962          KA+  1.3 OBSESSION PACK       3    Ess.
# 54963          KA+        1.3 ORIGINAL       3    Ess.
#
#                            Boite CO2\n(g/km) prix_neuf  \
# 12414  Boite de vitesse manuelle  154 (nedc)  10 600 €
# 12415  Boite de vitesse manuelle  154 (nedc)  12 540 €
# 12416  Boite de vitesse manuelle  154 (nedc)   9 700 €
# 12417  Boite de vitesse manuelle  154 (nedc)  10 400 €
# 12418  Boite de vitesse manuelle          NC   8 900 €
# ...                          ...         ...       ...
# 54959  Boite de vitesse manuelle  154 (nedc)  10 600 €
# 54960  Boite de vitesse manuelle  154 (nedc)  12 540 €
# 54961  Boite de vitesse manuelle  154 (nedc)   9 700 €
# 54962  Boite de vitesse manuelle  154 (nedc)  10 400 €
# 54963  Boite de vitesse manuelle          NC   8 900 €
#
#                                            url_prix_neuf option_marque_select  \
# 12414  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 12415  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 12416  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 12417  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 12418  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# ...                                                  ...                  ...
# 54959  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 54960  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 54961  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 54962  https://www.caradisiac.com/fiches-techniques/m...                 FORD
# 54963  https://www.caradisiac.com/fiches-techniques/m...                 FORD
#
#        option_year_select Version_selected
# 12414                2017          FORD KA
# 12415                2017          FORD KA
# 12416                2017          FORD KA
# 12417                2017          FORD KA
# 12418                2017          FORD KA
# ...                   ...              ...
# 54959                2018          FORD KA
# 54960                2018          FORD KA
# 54961                2018          FORD KA
# 54962                2018          FORD KA
# 54963                2018          FORD KA
#
# [777 rows x 11 columns]

# %% [markdown]
# ## 4. Traitement des valeurs manquantes

# %%
# Liste des missing values
missing_values = df.isnull().sum()
print(missing_values)

# %%
# Supprimer les lignes où le prix est manquant
df.dropna(subset=["prix"], inplace=True)
missing_values = df.isnull().sum()
print(missing_values)

# %% [markdown]
# Il reste 256 lignes où l'émission de CO2 et le top usage_commerciale_anterieure sont vides

# %%
df_missing = df[(df["emission_CO2"].isnull()) | 
                (df["usage_commerciale_anterieure"].isnull())
                ]
print(df_missing.shape)
df_missing.head()

# %%
# Regarder si emission_CO2 est renseignée quelque part pour les voitures de même modèle et finition
# La liste des valeurs uniques de emission_CO2 pour chaque modèle et finition
df_emission_CO2_stats = df[df["emission_CO2"].notnull()].groupby(["annee", "modele", "finition"]) \
    .agg({"emission_CO2": ["nunique", "min", "max", "mean"]}) \
    .reset_index()

# Rename the column ('annee', '') to 'annee'
df_emission_CO2_stats.columns = ['annee', 'modele', 'finition', 'nunique', 'min', 'max', 'mean']

# Sort the dataframe by the number of unique values in emission_CO2
df_emission_CO2_stats = df_emission_CO2_stats.sort_values("nunique", ascending=False)

# Si emission_CO2 est missing, on prend la moyenne de emission_CO2 pour l'année, le modèle et la finition
df_missing = df_missing.merge(df_emission_CO2_stats[["annee", "modele", "finition", "mean"]],
                               how="left",
                               on=["annee", "modele", "finition"])
df_missing.rename(columns={"mean": "emission_CO2_mean"}, inplace=True)
df_missing["emission_CO2"] = df_missing["emission_CO2"].fillna(df_missing["emission_CO2_mean"])

# %%
# Nombre de missing values après le remplissage
missing_values = df_missing.isnull().sum()
print(missing_values)

# %%
# Sur les missing values restants, on remplace emission_CO2 par la moyenne de emission_CO2 pour le modèle
df_emission_CO2_stats_2= df[df["emission_CO2"].notnull()].groupby(["modele", "finition"]) \
                                .agg({"emission_CO2": ["nunique", "min", "max", "mean"]}) \
                                .reset_index()

# Rename the column ('annee', '') to 'annee'
df_emission_CO2_stats_2.columns = ['modele', 'finition', 'nunique', 'min', 'max', 'mean']

# Imputer les valeurs manquantes restantes de emission_CO2 
# par la moyenne de emission_CO2 pour le modèle et la finition
df_missing = df_missing.merge(df_emission_CO2_stats_2[["modele", "finition", "mean"]],
                               how="left",
                               on=["modele", "finition"])
df_missing.rename(columns={"mean": "emission_CO2_mean_2"}, inplace=True)
df_missing["emission_CO2"] = df_missing["emission_CO2"].fillna(df_missing["emission_CO2_mean_2"])
df_missing.drop(columns=["emission_CO2_mean", "emission_CO2_mean_2"], inplace=True)

# Nombre de missing values après le remplissage
missing_values = df_missing.isnull().sum()
print(missing_values)

# %% [markdown]
# Sur les cas qui restent, imputer comme suit:
# - emission_C02: moyenne d'émission par marque et carburant
# - usage_commerciale_anterieure: utiliser mode

# %%
# Liste des colonnes alphanumériques
alphanumeric_columns = df.select_dtypes(include=[object]).columns.tolist()
print(alphanumeric_columns)

# %%
# Les valeurs uniques de chaque colonne alphanumérique
# exclure les colonnes dans list_of_columns_to_drop
# afficher les 10 valeurs les plus fréquentes
list_of_columns_to_drop = ['scraped_at', 'url_annonce', 'annee_mise_en_circulation']
for col in alphanumeric_columns:
    if col in list_of_columns_to_drop:
        continue    
    print(f"Colonne: {col}")
    value_counts = df[col].value_counts(normalize=True, dropna=False).head(10)
    absolute_counts = df[col].value_counts(dropna=False).head(10)
    percentages = (value_counts * 100).round(2).astype(str) + " %"
    print(pd.DataFrame({'Valeur': absolute_counts.index, 
                        'Fréquence': absolute_counts.values, 
                        'Pourcentage': percentages.values
                        }
                        ).reset_index(drop=True)
        )
    print("===" * 20)

# %%
# Histogramme

# %%
df.describe(include = "object")

# %%
df.describe(include="number")

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)

# %%
df_missing_prix = df[df["prix"].isnull()]
df_missing_prix.head()

# %%
count = df["modele"].value_counts()

# %%
count.reset_index()

# %%
df.shape
